# %% [markdown]
# ## Learning to Write Research Papers:
# - Today we'll talk about writing research papers
#     - They are different from lab reports, but a lot is similar
#     - It is a significant leap from creative or journalistic writing to research writing
#     - Respect that gap and focus on it, and you'll learn quickly
# - The best way to prepare for writing papers is to read papers, focusing on the writing as well as the content
#     - Identify the writing style common to all papers
#     - See what you need to explain and what you can assume
#     - Look at the kinds of arguments raised, when to cite other work, what is in figures and tables, etc.
#     - Each journal has a style guideline, usually detailed, that you must follow.  Read a few of these along with a paper from each journal (e.g, [ApJ](https://arxiv.org/pdf/2310.03792.pdf); [ApJ Letters](https://iopscience.iop.org/article/10.3847/2041-8213/acc4b6); [A&A](https://arxiv.org/pdf/2310.03845.pdf); [Icarus](https://www.sciencedirect.com/science/article/pii/S0019103523002439); [Nature Astronomy](https://www.nature.com/articles/s41550-023-02040-7); [Science](https://arxiv.org/pdf/2212.00034.pdf) )

# %% [markdown]
# ## Discussion of a paper vs a report:
# - 3 rules of Communication:
#     1. Know your subject.
#     2. Know your audience.
#     3. Know what you want your audience to know about your subject.
#
#
# - Think:
#     - Who is the audience of the paper? Who of a public article/ report etc?
#     - What do the authors want to accomplish by publishing the article?
#
#
# - Go through this [paper](https://www.nature.com/articles/s41561-023-01281-5?utm_medium=affiliate&utm_source=commission_junction&utm_campaign=CONR_PF018_ECOM_GL_PHSS_ALWYS_DEEPLINK&utm_content=textlink&utm_term=PID100052171&CJEVENT=83a5866e66df11ee82c503250a1eba23) and a [popular article](https://www.space.com/mercury-is-probably-still-shrinking-today) about its findings and discuss:
#     - What do the authors present, and in what order?
#     - What do they need to do to convince people it's right?
#     - How did they do that?
#     - Discuss the paper and the writing techniques used in each

# %% [markdown]
# ### Unlike your reports or popular articles science papers need to be **concise**

# %% [markdown]
# -A few examples of report vs paper writting follow:
#
#    - """Polarimetry is especially useful in identifying whether reflection is coming from a surface or a cloud deck, making it highly applicable to studies of habitable worlds. Different surfaces polarize light in different ways, which can be observed more easily in polarimetry than in unpolarized measurements. Additionally, differentiating an atmospheric spectrum probing only to a cloud layer as opposed to down to the surface of a planet is possible in polarized reflected light even at shorter wavelengths (e.g., Fauchez et al. 2017). Since studies into habitability require conditions near the surface of a terrestrial planet to be probed, this is an important distinction to make. """ <br><br> vs <br><br>"""polarimetry is especially useful in identifying whether reflection is coming from an absorptive surface or a cloud deck, making it highly applicable to studies of habitable worlds (e.g., Fauchez et al. 2017) """

# %% [markdown]
#
#   - or: <br> """As discussed in Section 1, Earthshine observations provide the greatest technique thus far for studying the signals of Earth as an exoplanet (i.e., the whole planet from a distance, rather than just localized regions observed from low-Earth orbiting satellites). Miles-P ́aez et al. (2014) provided the first linear spectropolarimetric measurements of the Earthshine from the visible to the near-infrared (NIR) wavelengths, thereby extending the knowledge of linear polarimetric Earthshine data into redder wavelengths than previous studies. Their team utilized the Andaluc ́ıa Faint Object Spectrograph and Camera (ALFOSC) instrument of the 2.56-m Nordic Optical Telescope (NOT) as well as the Long-slit Intermediate Resolution Infrared Spectrograph (LIRIS) of the 4.2-m William Herschel Telescope (WHT) to capture simultaneous optical (ALFOSC, 0.4 - 0.9 μm) and near-infrared (LIRIS, 0.9 - 2.3 μm) linear spectropolarimetric data of the Earthshine...The Earthshine observations have spectral resolutions of 2.51 nm in the optical (ALFOSC, 0.4 - 0.9 μm) and 1.83 nm (LIRIS, 0.9 - 1.5 μm) and 2.91 nm (LIRIS, 1.4 - 2.4 μm) in the near-infrared, capable of resolving major molecular atmospheric species.  """ <br><br> vs <br><br> """ Miles-P ́aez et al. (2014) provided the first linear spectropolarimetric measurements of the earthshine in the VNIR wavelengths. Miles-P ́aez et al. (2014) utilized the Andaluc ́ıa Faint Object Spectrograph and Camera (ALFOSC) instrument of the 2.56 m Nordic Optical Telescope (NOT) as well as the Long-slit Intermediate Resolution Infrared Spectrograph (LIRIS) of the 4.2 m William Herschel Telescope (WHT) to capture simultaneous optical (ALFOSC; 0.4 - 0.9 μm, spectral resolution of 2.51 nm) and NIR (LIRIS; 0.9 - 1.4 μm, spectral resolution of 1.83 nm; 1.4 - 2.4 μm, spectral resolution of 2.91 nm) linear spectropolarimetric observations of the earthshine, thereby extending the knowledge of linear polarimetric earthshine data into redder wavelengths than previous studies and allowing for the detection of important biosignature features not found at visible wavelengths."""

# %% [markdown]
#   - or: <br><br> """Figure N displays two plots using the Lambertian DAP Code, each plot containing five lines representing one of the five different surfaces as provided in the legend. On the left shows the resulting polarization for clear, cloudless atmospheres. The right shows the resulting polarization for atmospheres containing one water cloud layer comprised of type B particles at a cloud top altitude of about 3 km with a cloud optical thickness equal to 8.....What is most important in Figure N is that on the right, we see that clouds play a very large role on the resulting polarization, and in fact, the contributions from nearly all of the surfaces become negligible. The reason for this is because the clouds increase the multiple scattering of the incident radiation, thereby randomizing the polarized vectors of this light which leads to more unpolarized background light and thus a lower overall degree of polarization. Additionally, the clouds block much more of incident the light from getting through and interacting with the surface, resulting in the lack of surface features and loss of the vegetation red edge in the right plot"""<br><br>vs <br><br>""" Figure N shows our model Ps as a function of $\lambda$ for the five different surfaces we consider in our models, and for clear atmospheres (top panel) and cloudy atmospheres (bottom panel). Our cloudy models contain one liquid water cloud layer comprised of type B particles, with bc = 8 and pc = 0.710 bar....As expected, the introduction of clouds in our model atmosphere reduces,or even erases, the impact of the surfaces on our spectra. The VRE that is easily detectable in the clear atmosphere models (top panel) is reduced in the cloudy models (bottom panel).These changes are due to the clouds blocking the incoming light and increasing the amount of multiple scattering, thus lowering Ps."""

# %% [markdown]
# ### see the patterns? avoid to much blabing, go straight to the point.
#
# - 'What is most important in fig X'....you wouldn't talk about it in the paper if it wasn't! needless info
# - 'As discussed in Section 1, Earthshine observations provide the greatest technique thus far for studying the signals of Earth as an exoplanet (i.e., the whole planet from a distance, rather than just localized regions observed from low-Earth orbiting satellites)'.....you already discussed it, don't spend time (and so many words) re-iterating things
#
#
# - *REMEMBER*: your audience are specialists in the field, maybe not the exact sub-sub-sub thing you work on so you do need to provide some background info, but:
#     - don't pretend you reinvent the wheel (don't spend time discussing things that are common knowledge in the field)
#     - if someone has done X before, briefly explain it and reference X for the reader that wants to know more details
#     - your figures *should* contain important info otherwise you wouldn't show them, avoid stating the obvious

# %% [markdown]
# ### Avoid terms we use in every day language that are meaningless/not quantitative enough. Few examples:
#    - "much stronger absorption" : what is 'much'? how 'much' is 'much'?
#        - better: 10% stronger
#    - "fairly good fit to the data": what is 'fairly'?
#        - better: $\chi^2$ of xyz

# %% [markdown]
# ## Parts of a Research Paper:
# - Each paper tells a narrative story, the argument that supports the paper's conclusions
# - Writing the first draft early in the research can help to drive the research toward a good paper
# - If you planned your research poorly, you may find yourself doing many unexpected calculations because your paper needs them!
# - So, plan a story from the beginning
#
#
#
#
# - A common set of sections for an observational paper is:
#     - Abstract: stands alone on abstract services, summarizes the work and results, usually one long paragraph
#     - Introduction: like a funnel that interests a wide swath of readers' minds and prepares them to read the paper; what has been done before? what is missing that this paper will shed light onto?
#     - Observations: lists and describes the data and their acquisition
#     - Data analysis: describes how the data were processed to get numbers and uncertainties
#     - Results (often named after the thing the data are about, such as "Orbit" or "Atmospheric Chemistry"): uses the numbers to constrain a theory
#     - Discussion: talks about implications and limitations, compares to other work, etc.
#     - Conclusions: NOT just a summary, talks about what this work enables, future work, etc.
#     - References: standard-format (for journal) entries for all cited literature
#
#
# - similar, for theory paper:
#     - Abstract
#     - Introduction
#     - The code: describe the code(s) used to make your models
#         - if new code, remember to add a validation subsection
#     - Results
#     - Discussion
#     - Conclusions
#     - References

# %% [markdown]
# ## The Abstract:
# - The abstract is all most people will read!
# - It appears on preprint servers and in literature searches
# - Summarize the goal, the approach, the result (style can differ between journals; compare ApJ and A&A)
# - Include the key numerical results (with uncertainties) that people might look for in the papers
# - Be terse, do not expand on anything
# - State any key claims
# - Describe anything major but not yet mentioned that the paper covers
#     - NOTE: *Nature* letters (only) do not have a real abstract. They have a "bold paragraph" that mostly serves this function.  It has a specific format and might not state numerical results.
#
# ## The Introduction:
# - It is meant for you to justify the need for this work
#     - What question are you addressing?
#     - Who will use the result?
# - Introduce background literature
# - Lay the stage by discussing prior studies and related work
# - State your approach to the work
# - End with a roadmap to the rest of the paper (in section 2, we discuss...)
#
# ## The Main Text:
# - The style is terse.  Space is at a premium.  So is the reader's time.
# - Do not explain things that are generally known
# - Keep the discussion at a high level
# - E.g.: Do not explain what a flat field is.  Rather, say your flat fields came from the difference between sky images at two different light levels, for example.
# - Keep the sections clear, and clearly organized
# - Examine each sentence and ask, can I take this out?  Each sentence should have a clear function.
# - Use short expressions: "because", not "due to the fact that"
# - But, make it no shorter than it needs to be.  You will have to develop judgement in this area by reading other papers.
# - Cite any argument or fact that comes from somewhere else
# - Cite all relevant research, or cite a review paper "and references therein"
#
#
# ## The Conclusions:
# - **This is not a rehash of the abstract!**
# - Summarize the claims and in briefest terms what you did to prove them
# - Then, talk about what this now enables
# - Who cares about this result?
# - Talk about the future, what the next steps are, what might be needed to get a better result or the next result
# - Finish with a strong sentence
#
# ## Paper Writing Style:
# - Paper style is unique, different from textbook or creative writing
# - You are writing for history.  You are writing *to* an editor with a budget of pages.
# - High-level.  Serious.  Unemotional.  Minimalist.  Concise!
# - Active voice, but avoid repeating "I"/"We"
#     - e.g, prefer 'Fig. N shows' rather than 'In Fig. N we show'
#
# - Think of what did the action and use that as the subject: "A quadratic fit the shifts..." rather than "A quadratic was fit to the shifts".
# - *Definitely* avoid a passive sentence ending in "by the author"!
#
# - Avoid references to your mental state or effort unless it affected the result ("this was hard", "after 27 hours I was finally able to", etc.).  Such references do not appear in professional work.
#
# - Use simple sentence structures and grammatical constructs.  Many of your readers will not be native English speakers.  Give them a break!
#
# - Engineer each sentence to a purpose.  Always ask:
#     - Can this be made shorter without losing information?
#     - Can this be made simpler?
#     - Exactly what information do I want to convey with this sentence?
#     - What information does this sentence need to be understood?
#     - What sentences need this sentence to be understood?
#     - What is the role of this sentence in the paper?
#     - "Write drunk, edit sober"
#
#
# - Get AND USE feedback
#     - Demand criticism, but don't take any of it personally.  It's about the paper, not you.
#     - If a reviewer or a reader said it, IT'S TRUE!
#         - That is, it's true that's what they read.  If it's not actually true, it's your fault for saying it so they interpreted it that way.  Fix it!
#
#     - Side note: Same goes for proposals. Aim to start early enough so that you have time for your peers to read it, give you comments, and you can work on fixing issues they identified.

# %% [markdown]
# ### ICA (10 min):
# - Read [this popular article](https://www.space.com/james-webb-space-telescope-trappist-1-flares-alien-life-search) and condense it in 1, max 2 paragraphs using scientific-paper-style writting
# - or, do the same with [this article](https://www.space.com/ceres-dwarf-planet-mysteries-formation-theory)

# %% [markdown]
# TRAPPIST-1, red dwarf star discovered in 2016, emits powerful blasts of energy as flares several times a day. This violent activity, common in red dwarfs, is studied to separate them from regular light coming from the star. With seven potentially Earth-like worlds, the flares have become a primary source of investigation, suggesting filtering out around 80% of flare-based radiation. Combined with observations from the JWST, the secondary atmospheres of planets can be studied and aid in the hunt for habitable conditions in the universe.

# %% [markdown]
# ### In [this example](https://www.overleaf.com/read/dhbgkdzprtkq) I show a template paper written in ApJ style. We are going to walk through the different things you need to keep in mind in LaTeX. Also, this link will stay active forever so you can drop in to check things when you write your real papers later on...

# %% [markdown]
# ### Your bibliography is an important part of your research paper. [ADS](https://ui.adsabs.harvard.edu/) is the astronomy database for all papers (even some scanned papers from the early 1900s!)
#    - all your references will go in your references.bib file (or whatever.bib, keep the .bib extension to know its your bibliography)
#    - search for the paper you want (e.g., let's try to search for paper from Prof. Dove. Search for "dove, adrienne"
#    - click on one of these. You will get the abstract.
#    - left side menu has a "export citation" button, click on it
#    - you can copy to your cliboard and paste into your references.bib file
#    - Tip: changing the ridiculous calling tags of ADS (e.g., 2023AdSpR..72.1861Y change into name2023) can be helpful when you write your paper and want to cite a paper
#        - think of needing to remember: \citet{2023ApJ...945..166G} benchmarked the models against Earthshine observations **vs** <br> \citet{Gordon} benchmarked the models against Earthshine observations

# %% [markdown]
# ### Think - Pair- Share (15min)
#
# ### Design a detailed observing plan or laboratory experiment that would allow you to measure the QE of a CCD. Discuss the light source (astronomical or lab) you might use and over what band passes you can work. How accurate a result would you expect for each case? (Howell Ch 3, exercise 3)

# %% [markdown]
# Using a laser where you can actually measure the number of photons that you send out.
#
# From the standard output of the CCD, it will tell you, suppose you know 10 photons are sent frmo the laser but your CCD only reads 9, then you know only 9/10 were detected.
#
# CCD, perhaps like visible spectrum because we tend to get a lot of information from visible spectrum.
#
# I feel like you could get pretty accurate with laser.

# %% [markdown]
# ### Think - Pair- Share (30 min)
#
# ### Let's simulate a toy observation of a star. Create a CCD with 2048 x 2048 pixels. Add random thermal noise to each pixel, assuming creation of up to 100 e-/pixel. At the center of the CCD and over a radius of 20 pixels (just use a 20 by 20 pixels box; ignore the PSF that we will discuss about later in class) assume a star that shines homogeneously across the R band (observation centered around $0.66\mu$m with a width of $\sim0.28\mu$m) . The star has a T= 5770K, R=1R$_\odot$ and lies at a distance of 0.1pc. Your telescope has a diameter of 10m and you can assume optical transmission of 1. Your integration time is 2 seconds. Assuming your only noise sources are the thermal and photon noise, what is your SNR? Plot your CCD image.

# %%
import numpy as np

CCD = np.zeros(4194304).reshape(2048, 2048)

for i in CCD:
    noise = np.random.uniform(0, 100)
    CCD.append(noise)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 7
#       5 for i in CCD:
#       6     noise = np.random.uniform(0, 100)
# ----> 7     CCD.append(noise)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'
