# %%
import numpy as np              # load numerical module
import matplotlib.pyplot as plt # load plotting module
import astropy.io.fits as fits  # get FITS 
import pandas as pd             # get pandas 


import matplotlib.ticker as ticker  #get tickers for your contour plots
from pylab import *
rc('axes', linewidth=2)            #make your plot boarders a bit broader
#rc('font', weight='normal')       #you could also decide to change fonts
import matplotlib.image as mpimg   #get image reading  
import matplotlib.colors as colorsplt #get the colors for contours etc

# %% [markdown]
# ### 1.  [Background video](https://www.ted.com/talks/hans_rosling_shows_the_best_stats_you_ve_ever_seen) before class (see BCA on Webcourses):
# - One of the most popular TED talks is a data presentation by Hans Rosling.
# - During the presentation, ask yourselves:
#     - What are the main points?  Why does Rosling make a TED talk?
#     - Which point is he most concerned about?
#     - How does he use the non-data elements of his presentation? (What does he have besides his computer?)
#     - What plotting methods does he use to show more than 2 dimensions of data on 2D plots?  Make a list as you watch.
#     - Note how simple and yet data-rich his plots are!

# %% [markdown]
# ## Discussion of Video (for in class):
# - What are the main points?  Why does Rosling make a TED talk?
# - Which point is he most concerned about?
# - How does he use the non-data elements of his presentation? (What does he have besides his computer?)
# - Reviewing the video, what plotting methods does he use to show more than 2 dimensions of data on 2D plots?
# - What methods does he use to show relationships in money, population, health?  How does he show clustering, changes over time, changes with respect to members of a like group?
# - What are some other methods you can think of to present data in 2D?
# - Always keep an eye out for interesting ways to present data, catalog for your future use
# - Just reading the matplotlib manual gives new ideas of how to present

# %% [markdown]
# ### 2.  [Background video](https://www.youtube.com/watch?v=Unzc731iCUY) before class (see BCA on Webcourses):
#
# - a great lecture from MIT's Patrick Winston  on how to do a good presentation
# - During the lecture, ask yourselves:
#     - What are the main points of this lecture?
#     - How do you prepare for a good presentation?
#     - What is the golden rule according to many of a good presentation?
#     - What are the key aspects you need to pay attention to when making a presentation?
#     - What is a common pitfall in talks?
#     - Who is a great audience to practice your talk with and have them judge it?

# %% [markdown]
# ### 2D plots:

# %%
#let's make a data set 
x = np.arange( 0, 100, 0.01 )
y = np.sin( 2 * np.pi * x )

# %%
#we can make a fast, dirty plot:
dm = plt.plot( x, y )

# %% [markdown]
# ### While this is ‘a’ plot, it is not ideal. What are x and y showing? Also, it is a bit small.  Let’s add titles (xlabel/ylabel) and increase the size of the figure (figsize). While at it, let’s also change the color of the line to red (color). You can find all colors [here](https://matplotlib.org/3.1.0/gallery/color/named_colors.html)

# %%
#define how big the plot will appear:
plt.figure( figsize = ( 12,4 ) )

#plot it using a red, solid line
plt.plot  ( x, y, color = 'firebrick' ) # (or 'r') (xkcd: color)

# add a label on the x-axis
plt.xlabel( 't' )

#add a label on the y-axis
dm = plt.ylabel( 'Sin[ 2 $\pi$ t ] ' )

# %% [markdown]
# ### Let’s change the linestyle to a dashed line. You can find all linestyles [here](https://matplotlib.org/3.1.0/gallery/lines_bars_and_markers/linestyles.html) . We will also increase the fontsize of our labels to be able to actually read them from the back of the room, and zoom in in 2 periods.

# %%
plt.figure( figsize = (5, 5 ) )
plt.plot  ( x, y, color = 'red', linestyle = '--' ) 
plt.xlabel( 't'                 , fontsize = 20 )
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 20 )

#limit x axis
plt.xlim( 0, 2.1 )

#make tick labels legible:
plt.yticks( fontsize = 16 )

#note that if I skip the np.arange all labels will be printed and they will 
#make a crowded/overlapping x axis mess
plt.xticks( np.arange(0.0,2.1,0.5), fontsize = 16 )


#add a title on the plot and make sure it has big enough font

dm = plt.title('My sin function', fontsize = 20)

# %% [markdown]
# ### One more thing that I like to change to make the plot better legible is the orientation and size of [tickmarks](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.tick_params.html) themselves.

# %%
plt.figure( figsize = (5, 5 ) )
plt.plot  ( x[x < 2.1], y[y < 2.1], color = 'red', linestyle = '--' ) 
plt.xlabel( 't'                 , fontsize = 16 )
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 16 )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure( figsize = (5, 5 ) )
# ----> 2 plt.plot  ( x[x < 2.1], y[y < 2.1], color = 'red', linestyle = '--' )
#       3 plt.xlabel( 't'                 , fontsize = 16 )
#       4 plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 16 )
#
# File c:\Users\Alex\anaconda3\envs\astroDATA\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# ...

# %%
plt.figure( figsize = (5, 5 ) )
plt.plot  ( x, y, color = 'red', linestyle = '--' ) 
plt.xlabel( 't'                 , fontsize = 16 )
plt.ylabel( 'Sin[ 2 $\pi$ t ] ' , fontsize = 16 )

#limit x axis
plt.xlim( 0, 2.1 )

#make tick labels legible:
plt.yticks( fontsize = 16 )

#note that if I skip the np.arange all labels will be printed and they will 
#make a crowded/overlapping x axis mess
plt.xticks( np.arange(0.0,2.1,0.5), fontsize = 16 )


#add a title on the plot and make sure it has big enough font

plt.title('My sin function', fontsize = 16)


#access and change the tick parameters for this plot:
dm = plt.tick_params(axis='both',which='major',length=8, width=1.5,direction='in')
#plt.tick_params(axis='both',which='minr',length=8, width=3,direction='in')

# %% [markdown]
# ### Let's move to another dataset now

# %%
x2  = np.arange( 20 )
y2a = 2.1*x2 + 3.1
y2b = 3.0*x2 + 2.5

# %% [markdown]
# #### plot both data in the same plot using different colors and linestyles. Add a [legend](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html) to indicate what is what. Note that we need to  define the labels first otherwise there is nothing for legend to display

# %%
plt.figure( figsize = (5, 5 ) )
plt.plot  ( x2, y2a, color = 'firebrick', linestyle = '--' , 
           linewidth = 2, label = 'model 1')
plt.plot  ( x2, y2b, color = 'cornflowerblue', linestyle = '-.' , 
           linewidth = 2, label = 'model 2')

#fix tick label size
plt.yticks( np.arange(10, 61, 20), fontsize = 16 )
plt.xticks( np.arange(0, 21, 5) , fontsize = 16 )


#add a title on the plot and make sure it has big enough font

plt.title('Two lines', fontsize = 16)

#access and change the tick parameters for this plot:
plt.tick_params(axis='both',which='major',length=8, width=1.5,direction='in')

#add a legend
dm = plt.legend( fontsize = 12, loc = 'upper left')

# %% [markdown]
# ### what if you want to use [markers](https://matplotlib.org/stable/api/markers_api.html) instead of lines?

# %%
plt.figure( figsize = (5, 5 ) )
plt.plot  ( x2, y2a, color = 'firebrick', linestyle = ' ' ,  #or = 'none' works the same
           marker ='s', label = 'model 1', markersize = 6)
plt.plot  ( x2, y2b, color = 'cornflowerblue', linestyle = ' ' , 
           marker = 'o', label = 'model 2', markersize = 6)

#fix tick label size
plt.yticks( np.arange(10, 61, 20), fontsize = 16 )
plt.xticks( np.arange(0, 21, 5) , fontsize = 16 )


#add a title on the plot and make sure it has big enough font

plt.title('Two lines', fontsize = 16)

#access and change the tick parameters for this plot:
plt.tick_params(axis='both',which='major',length=8, width=1.5,direction='in')

#add a legend
dm = plt.legend( fontsize = 12, loc = 'upper left')

# %% [markdown]
# ### ICA: Read first_data_read_plot.dat and read it in with loadtxt. The dataset contains HST WFC3/G141 spectra from a brown dwarf. Plot the two spectra in the same plot making it publication ready.

# %%
spectra = np.loadtxt("first_data_read_plot.dat")
# Out:
# [[1.1  0.72 0.75]
#  [1.11 0.73 0.7 ]
#  [1.11 0.69 0.65]
#  [1.11 0.68 0.62]
#  [1.12 0.66 0.7 ]
#  [1.12 0.69 0.69]
#  [1.13 0.66 0.7 ]
#  [1.13 0.63 0.72]
#  [1.14 0.63 0.66]
#  [1.14 0.63 0.66]
#  [1.14 0.65 0.65]
#  [1.15 0.69 0.72]
#  [1.15 0.69 0.73]
#  [1.16 0.67 0.72]
#  [1.16 0.66 0.72]
#  [1.17 0.66 0.67]
#  [1.17 0.65 0.62]
#  [1.17 0.64 0.66]
#  [1.18 0.67 0.67]
#  [1.18 0.74 0.75]
#  [1.19 0.78 0.81]
#  [1.19 0.8  0.83]
#  [1.19 0.81 0.86]
#  [1.2  0.82 0.88]
#  [1.2  0.83 0.92]
#  [1.21 0.87 0.91]
#  [1.21 0.9  0.95]
#  [1.22 0.93 0.95]
#  [1.22 0.94 1.  ]
#  [1.22 0.98 1.02]
#  [1.23 0.98 1.01]
#  [1.23 0.97 1.  ]
#  [1.24 0.97 0.97]
#  [1.24 0.99 1.01]
#  [1.25 0.96 0.95]
#  [1.25 1.   1.  ]
#  [1.26 1.04 1.02]
#  [1.26 1.09 1.06]
#  [1.26 1.08 1.06]
#  [1.27 1.09 1.07]
#  [1.27 1.07 1.09]
#  [1.28 1.08 1.1 ]
#  [1.28 1.04 1.07]
#  [1.29 1.08 1.06]
#  [1.29 1.06 1.07]
#  [1.29 1.08 1.09]
#  [1.3  1.07 1.07]
#  [1.3  1.07 1.05]
#  [1.31 1.06 1.05]
#  [1.31 1.06 1.01]
# ...

# %%
wav = spectra[:,0]
flux1 = spectra[:,1]
flux2 = spectra[:,2]

# %%
plt.figure()
#plt.plot  ( wav, flux1, color = 'firebrick', linestyle = ' ' ,  #or = 'none' works the same#
#           marker ='s', label = 'Flux 1', markersize = 6)
#plt.plot  ( wav, flux2, color = 'cornflowerblue', linestyle = ' ' , 
#           marker = 'o', label = 'FLux 2', markersize = 6)

plt.scatter  ( wav, flux1, color = 'firebrick', marker = 'x', label = 'Spectrum 1')
plt.scatter  ( wav, flux2, color = 'cornflowerblue', marker = 'x', label = 'Spectrum 2')

#add a title on the plot and make sure it has big enough font

plt.title('Spectras', fontsize = 16)

#access and change the tick parameters for this plot:
plt.tick_params(axis='both',which='major',length=8, width=1.5,direction='in')

#add a legend
dm = plt.legend( fontsize = 12, loc = 'upper left')

# %% [markdown]
# ### In research you might also need to work with images. You can find all info you will need for that [here]( https://matplotlib.org/stable/tutorials/images.html)

# %% [markdown]
# ### Let's read the image *jup_hst_nasa.png*

# %%
import matplotlib.image as mpimg 
img = mpimg.imread( 'jup_hst_nasa.png' )

# %%
#to just plot it directly:
imgplot = plt.imshow(img)

# %%
#notice though that it is a 1400x1400x3 cube:
img.shape
# Out:
# (1400, 1400, 3)

# %%
for i in range(3):
    limg = img[ :, :, i]
    imgplot = plt.imshow( limg, cmap = 'RdYlBu' )
    plt.colorbar()
    plt.show()

# %%
#can you guess the difference?

# %% [markdown]
# ### you might need to annotate an element in your image:

# %%
limg = img[ :, :, 2]
imgplot = plt.imshow( limg, cmap = 'RdYlBu' )

#add text that highlights the GRS
plt.text( 440, 850, 'GRS', color='black', fontsize = 14)

dm = plt.colorbar()

# %%
#or I can add an arrow annotation:
limg = img[ :, :, 2]
imgplot = plt.imshow( limg, cmap = 'RdYlBu' )

# add arrow annotation:
plt. annotate( 'GRS', xy=(400, 850 ), xytext=( 600 , 800), fontsize = 16,
            arrowprops=dict(facecolor='black', shrink=0.01),
            )

dm = plt.colorbar()

# %% [markdown]
# ### If you want to add more flexibility to your plots, and start making more advanced/ multiple plots you can do more object-oriented plots using the 'ax'

# %%
#let's make a basic plot of x vs y for this random sinusoidal data:
x = np.linspace( 0, 15, 1000 )
y = np.sin( x )

# %%
fig, ax = plt.subplots( figsize = (4, 3) )  # create a figure object

ax.plot( x, y , linewidth = 4)                     #make the plot 
ax.set_ylabel( 'Y', color='firebrick', fontsize=20 )    # add X and Y labels and make them red
ax.set_xlabel( 'X', color='blue', fontsize=20 )
ax.tick_params( axis="both", labelsize=18 )       # change the size of your tick labels

# %% [markdown]
# ### this method offers you more flexibility than the plt--- for example, you can use double y axis in a plot:  (note: same principles for double x axis)

# %%
#make a new x axis:
x = np.linspace(0., 10., 100)

fig = plt.figure( figsize = (6,5) )

#I will start with ax1 
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot( x, x ** 2, color= 'blue' , linewidth = 3 )
#I can rotate the y label 
ax1.set_ylabel( 'x$^2$', color='blue', fontsize=24, rotation = 0 )
ax1.set_xlabel('x',fontsize=20)
ax1.tick_params( axis="both", labelsize=18, length = 7 , direction = 'in' )

#but then I want a secondary y axis, so I need to make an ax1 twin named ax2
ax2 = ax1.twinx()

ax2.plot( x, 1/x, color='red')
#and this one I will leave the label as is
ax2.set_ylabel('$ \\frac{1}{x} $', color='red',fontsize=24) #, rotation = 0)
dm = ax2.tick_params( axis="y", labelsize=18 , length = 7 , direction = 'in' )
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\2297765465.py:18: RuntimeWarning: divide by zero encountered in divide
#   ax2.plot( x, 1/x, color='red')

# %%
#notice how different that is from the 'normal' 2 in 1 plot:
plt.plot( x, x ** 2, color= 'blue' , linewidth = 3)
dm = plt.plot(x, 1/x, color='red')
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\3641525881.py:3: RuntimeWarning: divide by zero encountered in divide
#   dm = plt.plot(x, 1/x, color='red')

# %% [markdown]
# ### with the ax method you can start making more complex plots

# %%
# I start by defining that I want 2 line 1 columns plot
fig, ( ax1, ax2 ) = plt.subplots(2, figsize = (10, 10 )) # this is 2,1 figures

fig.suptitle('Vertically stacked scatter plots example' , fontsize = 24 )

#start with the first one:

ax1.plot( x , x**2 )
ax1.set_xlabel( ' x ' , fontsize = 14 )
ax1.set_ylabel( ' $x^2$' , fontsize = 14 )

#you can define what your tickmarks will be via the set_xticks (or y) and _xticklabels
ax1.tick_params( axis="both", labelsize=18, length = 7 , direction = 'in' )

# go to the second one:

ax2.plot( x, 1/x , color = 'red' ) 
ax2.set_xlabel( ' x ' , fontsize = 14 )
ax2.set_ylabel( r' $\frac{1}{x}$ ' , fontsize = 14 )

dm = ax2.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' , labelsize=14 )
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\2593539769.py:17: RuntimeWarning: divide by zero encountered in divide
#   ax2.plot( x, 1/x , color = 'red' )

# %%
# but I realized I needed 2 columns 1 line plot to make it look better
fig, ( ax1, ax2 ) = plt.subplots(1, 2, figsize = (12, 6 )) # this is 1,2 figure

fig.suptitle('Horizontally stacked scatter plots example' , fontsize = 24 )

#start with the first one:

ax1.plot( x , x**2 )
ax1.set_xlabel( ' x ' , fontsize = 14 )
ax1.set_ylabel( ' $x^2$' , fontsize = 14 )

#you can define what your tickmarks will be via the set_xticks (or y) and _xticklabels
ax1.tick_params( axis="both", labelsize=18, length = 7 , direction = 'in' )

# go to the second one:

ax2.plot( x, 1/x , color = 'red' ) 
ax2.set_xlabel( ' x ' , fontsize = 14 )
ax2.set_ylabel( r' $\frac{1}{x}$ ' , fontsize = 14 )

dm = ax2.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' , labelsize=14 )
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\2669487806.py:17: RuntimeWarning: divide by zero encountered in divide
#   ax2.plot( x, 1/x , color = 'red' )

# %%
#you can image that this can become more complex....

fig, ( (ax1, ax2), (ax3, ax4) ) = plt.subplots( 2, 2 , figsize = (16, 16 ) )

#start with the first one:

ax1.plot( x , x**2 )
ax1.set_xlabel( ' x ' , fontsize = 14 )
ax1.set_ylabel( ' $x^2$' , fontsize = 14 )

#you can define what your tickmarks will be via the set_xticks (or y) and _xticklabels
ax1.tick_params( axis="both", labelsize=18, length = 7 , direction = 'in' )

# go to the second one:

ax2.plot( x, 1/x , color = 'red' ) 
ax2.set_xlabel( ' x ' , fontsize = 14 )
ax2.set_ylabel( r' $\frac{1}{x}$ ' , fontsize = 14 )
ax2.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' , labelsize=14 )


#move to the third
ax3.plot( x, 1/x**2 , color = 'orange' ) 
ax3.set_xlabel( ' x ' , fontsize = 14 )
ax3.set_ylabel( r' $\frac{1}{x^3}$ ' , fontsize = 14 )
ax3.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' , labelsize=14 )


#and lastly the fourth; BUT crank up the accuracy for the reader:
ax4.plot( x, np.log10(x) , color = 'green' ) 
ax4.set_xlabel( ' x ' , fontsize = 14 )
ax4.set_ylabel( r' $\log_{10}x$ ' , fontsize = 14 )
ax4.grid( linestyle='--' )
dm = ax4.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' , labelsize=14 )
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\551946555.py:16: RuntimeWarning: divide by zero encountered in divide
#   ax2.plot( x, 1/x , color = 'red' )
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\551946555.py:23: RuntimeWarning: divide by zero encountered in divide
#   ax3.plot( x, 1/x**2 , color = 'orange' )
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\551946555.py:30: RuntimeWarning: divide by zero encountered in log10
#   ax4.plot( x, np.log10(x) , color = 'green' )

# %% [markdown]
# ### often you will need to use contours to highlight a 3rd dimension in your data; or colorbars to show the levels that your data/image shows (we have already seen a number of colorbars with imshow() )

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7))
#make dataset
delta = 0.025
x    = np.arange( -5, 5, 0.1 )
y    = np.arange( -5.0, 5.0, delta )
xx, yy = np.meshgrid( x, y , sparse=True )

z = np.sin( xx**2 + yy**2 ) / ( xx**2 + yy**2 )

#normalize the data for colorbar and let code know you use 256 colors
bounds = np.linspace( np.min( z ) , np.max( z ) + .1, 100)
norm = colorsplt.BoundaryNorm(boundaries=bounds, ncolors=256)

#define the filled contour plot
pcm = ax.contourf(x, y ,z ,100, cmap='RdYlBu')

#define that you want its colorbar
cbar = fig.colorbar( pcm,fraction=0.045, pad=0.01 )

#add the cosmetic stuff:
cbar.set_label('random contour',fontsize = 20 )
cbar.ax.tick_params(labelsize = 20)

ax.tick_params( axis ='both', which ='both', length = 7 , direction = 'in', width = 3 )
ax.set_xticklabels( -6. + np.arange( 6 ) *2, fontsize = 20)
dm = ax.set_yticklabels( -6. + np.arange( 6 ) *2, fontsize = 20)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\4266068080.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels( -6. + np.arange( 6 ) *2, fontsize = 20)
# C:\Users\Alex\AppData\Local\Temp\ipykernel_9436\4266068080.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   dm = ax.set_yticklabels( -6. + np.arange( 6 ) *2, fontsize = 20)

# %%
# or you can do a contour plot that is not filled in:

fig, ax = plt.subplots( figsize = ( 12, 8 ) )

CS = ax.contour( x, y, z )
ax.clabel( CS, inline=1, fontsize=12 )
ax.set_title( 'Simple contour plot with labels' , fontsize = 20 )

ax.set_xlabel( 'X' , fontsize = 24 )
ax.set_ylabel( 'Y' , fontsize = 24 )
ax.tick_params( axis="both", labelsize=20 ) 
ax.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' )

# %%
# you can use color maps:
fig, ax = plt.subplots( figsize = ( 12, 8 ) )

CS = ax.contour( x, y, z, cmap = 'rainbow',
                )

ax.clabel( CS, fontsize = 14, inline = True )
ax.set_title( 'Crazy lines', fontsize = 24)

ax.set_xlabel( 'X' , fontsize = 24 )
ax.set_ylabel( 'Y' , fontsize = 24 )
ax.tick_params( axis="both", labelsize=20 ) 
ax.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' )

# %%
# you can also manually define the properties of your lines:
delta = 0.025
x = np.arange( -3.0, 3.0, delta )
y = np.arange( -2.0, 2.0, delta )
X, Y = np.meshgrid(x, y)

Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z  = (Z1 - Z2) * 2

fig, ax = plt.subplots( figsize = ( 12, 8 ) )

CS = ax.contour( X, Y, Z, 6,
                linewidths = np.arange(1, 7, 1),
                colors = ('red', 'green', 'blue', 'orange', 'magenta', 'gray'),
                )

ax.clabel( CS, fontsize = 14, inline = True )
ax.set_title( 'Crazy lines', fontsize = 24)

ax.set_xlabel( 'X' , fontsize = 24 )
ax.set_ylabel( 'Y' , fontsize = 24 )
ax.tick_params( axis="both", labelsize=20 ) 
ax.tick_params( axis ='both', which ='both', length = 7 , direction = 'in' )

# %% [markdown]
# # ---------------------------------------------------------------
# # Colorblind friendly plots

# %% [markdown]
# <img src="ishiharas_test.png" width=550 height=250 />
#
# source: https://www.color-blindness.com/ishiharas-test-for-colour-deficiency-38-plates-edition/

# %% [markdown]
# <img src="retinas.png" width=550 height=550 />
#
# Souce:BenRG - Own work, Public Domain, https://commons.wikimedia.org/w/index.php?curid=7873848

# %% [markdown]
# <img src="colorblidness_states.png" width=550 height=550 />
# source: By Nanobot - Own work, Public Domain,https://commons.wikimedia.org/w/index.php?curid=7905402

# %% [markdown]
# ### How do you ensure that colorblind people can see your plots as they should be seen?
# #### community has created number of resources that you can use to plot colorblind-friendly plots; here I show just one from an old colleague
#
# <img src="colorblind_friendly.png" width=550 height=550 />
#
# source: https://personal.sron.nl/~pault/

# %%
from tol_colors import tol_cset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 from tol_colors import tol_cset
#
# ModuleNotFoundError: No module named 'tol_colors'

# %%
schemes = tol_cset()

fig, axes = plt.subplots(ncols=len(schemes))
fig.subplots_adjust(top=0.92, bottom=0.02, left=0.02, right=0.92)
for ax, scheme in zip(axes, schemes):
        cset = tol_cset(scheme)
        names = cset._fields
        colors = list(cset)
        for name, color in zip(names, colors):
            ax.scatter([], [], c=color, s=80, label=name)
        ax.set_axis_off()
        ax.legend(loc=2)
        ax.set_title(scheme)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 schemes = tol_cset()
#       3 fig, axes = plt.subplots(ncols=len(schemes))
#       4 fig.subplots_adjust(top=0.92, bottom=0.02, left=0.02, right=0.92)
#
# NameError: name 'tol_cset' is not defined

# %%
x = np.arange( 10 )
y = x ** 2.
z = x ** 0.5
w = x ** 1.5


clrs = tol_cset( colorset= 'bright' )

#add your plot here:
plt.figure( figsize =( 12, 7 ) )

plt.plot( x, y, linewidth =3 , color = clrs[0] )
plt.plot( x, z, linewidth =3 , color = clrs[3] )
plt.plot( x, w, linewidth =3 , color = clrs[5] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 7
#       3 z = x ** 0.5
#       4 w = x ** 1.5
# ----> 7 clrs = tol_cset( colorset= 'bright' )
#       9 #add your plot here:
#      10 plt.figure( figsize =( 12, 7 ) )
#
# NameError: name 'tol_cset' is not defined

# %% [markdown]
# ### Last, but not least, some times you might need to plot things in real 3D (not 2D+contour colors). If you want to learn more things about 3D plotting look at:
#
# ### Quickest, simplest, but not as much detailed control:  http://vpython.org/
#
# ### All the basics, and much more, good control of details: http://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html
#
# ### Bells and whistles, including speed optimization and volume rendering:  http://docs.enthought.com/mayavi/mayavi/mlab.html

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
#make random data- from https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html:

theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)


fig = plt.figure( figsize = ( 10, 10 ) )
ax = fig.add_subplot(projection='3d')
ax.plot(x, y, z, label='parametric curve')
dm = ax.legend()

# %%
###----> start an interactive window:
## import matplotlib
#matplotlib.use('TkAgg') 
# %matplotlib inline

# %%
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)


fig = plt.figure( figsize = ( 10, 10 ) )
ax = fig.add_subplot(projection='3d')
ax.plot(x, y, z, label='parametric curve')
dm = ax.legend()

# %%
# you can now decide to plot back in line:

# %matplotlib inline

# %% [markdown]
# ### Think-Pair-Share (25 min)
#
# ### JWST has given us the best spectrum of exoplanet VHS 1256b. You can find the data in file: *VHS1256b_V2.txt* (from Miles et al 2023). What is the $T_\mathrm{eff}$ of this planet?
#
# - read the data using pandas
# - plot the spectrum
#
# - like all planets/exoplanets/brown dwarfs the atmosphere is molecular and shows strong absorption from different molecules. Ingoring the absorption and assuming the atmosphere is a black body use astropy's black body function (https://docs.astropy.org/en/stable/api/astropy.modeling.physical_models.BlackBody.html) and fit the spectrum to identify the $T_\mathrm{eff}$ of the atmosphere
#     - what are the parameters you need to take into account?
#     - test $T_\mathrm{eff}$ of 2000K, 1750K, 1500K, 1250K, 1000K and 750 K.
#     - code a (manual) least squares fitting
#
# - Get pickle with BT Settl models (source: http://svo2.cab.inta-csic.es/theory/newov2/index.php) and fit observations. What are the properties of the atmosphere?
